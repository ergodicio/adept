# %%
import orthax
import jax
import jax.numpy as jnp

# %%
v = jnp.linspace(-10, 10, 2000)
M = 20
series = jnp.zeros(M+1).at[M].set(1)
orthax.hermite_e.hermeval(v, series)
# Out:
# Array([8.8167116e+18, 8.5855146e+18, 8.3599932e+18, ..., 8.3600146e+18,
#        8.5855569e+18, 8.8167116e+18], dtype=float32)

# %%
32 * 32 * (20 * 10) / (0.005**2)
# Out:
# 8192000000.0
